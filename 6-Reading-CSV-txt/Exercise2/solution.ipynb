# %% [markdown]
# # Solução

# %%
import numpy as np
import pandas as pd

# %%
col_names = ['Title', 'Air date', 'Production code', 'Season', 'Number in season',
             'Number in series', 'US viewers (million)', 'Views', 'IMDB rating']

select_cols = ['Title','Air date','Production code','IMDB rating']

df = pd.read_csv('files/simpsons-episodes.tsv',
                 header=None,
                 names=col_names)

df.head()
# Out:
#                                                Title  Air date  \
# 0  Two Cars in Every Garage and Three Eyes on Eve...       NaN
# 1   no_val\t15/11/90\t7F08\t2\t6\t19\t25.4\t50691\t8       NaN
# 2  Bart the Daredevil\t6/12/90\t7F06\t2\t8\t21\t2...       NaN
# 3  Bart Gets Hit by a Car\t10/1/91\tno_val\t2\t10...       NaN
# 4  Homer vs. Lisa and the 8th Commandment\t7/2/91...       NaN
#
#    Production code  Season  Number in season  Number in series  \
# 0              NaN     NaN               NaN               NaN
# 1              NaN     NaN               NaN               NaN
# 2              NaN     NaN               NaN               NaN
# 3              NaN     NaN               NaN               NaN
# 4              NaN     NaN               NaN               NaN
#
#    US viewers (million)  Views  IMDB rating
# 0                   NaN    NaN          NaN
# 1                   NaN    NaN          NaN
# 2                   NaN    NaN          NaN
# 3                   NaN    NaN          NaN
# 4                   NaN    NaN          NaN

# %% [markdown]
# Note que o separador entre os dados é o '\t'

# %%
col_names = ['Title', 'Air date', 'Production code', 'Season', 'Number in season',
             'Number in series', 'US viewers (million)', 'Views', 'IMDB rating']

df = pd.read_csv('files/simpsons-episodes.tsv',
                 header=None,
                 names=col_names,
                 sep='\t')

df.head()
# Out:
#                                                Title Air date Production code  \
# 0                                                NaN      NaN             NaN
# 1                                                NaN      NaN             NaN
# 2                                                NaN      NaN             NaN
# 3                                                NaN      NaN             NaN
# 4  Two Cars in Every Garage and Three Eyes on Eve...  1/11/90            7F01
#
#   Season  Number in season  Number in series US viewers (million)    Views  \
# 0    NaN               NaN               NaN                  NaN      NaN
# 1    NaN               NaN               NaN                  NaN      NaN
# 2    NaN               NaN               NaN                  NaN      NaN
# 3    NaN               NaN               NaN                  NaN      NaN
# 4      2               4.0              17.0                 26.1  64959.0
#
#   IMDB rating
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         8.1

# %% [markdown]
# Precisamos ignorar as linhas [1,4]

# %%
col_names = ['Title', 'Air date', 'Production code', 'Season', 'Number in season',
             'Number in series', 'US viewers (million)', 'Views', 'IMDB rating']

df = pd.read_csv('files/simpsons-episodes.tsv',
                 header=None,
                 names=col_names,
                 sep='\t',
                 skiprows=4)

df.head()
# Out:
#                                                Title  Air date  \
# 0  Two Cars in Every Garage and Three Eyes on Eve...   1/11/90
# 1                                             no_val  15/11/90
# 2                                 Bart the Daredevil   6/12/90
# 3                             Bart Gets Hit by a Car   10/1/91
# 4             Homer vs. Lisa and the 8th Commandment    7/2/91
#
#   Production code Season  Number in season  Number in series  \
# 0            7F01      2                 4                17
# 1            7F08      2                 6                19
# 2            7F06      2                 8                21
# 3          no_val      2                10                23
# 4            7F13      2                13                26
#
#   US viewers (million)    Views IMDB rating
# 0                 26.1  64959.0         8.1
# 1                 25.4  50691.0           8
# 2                 26.2  57605.0      no_val
# 3                 24.8  56486.0         7.8
# 4                 26.2  58277.0           8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 597 entries, 0 to 596
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Title                 597 non-null    object
#  1   Air date              597 non-null    object
#  2   Production code       597 non-null    object
#  3   Season                597 non-null    object
#  4   Number in season      597 non-null    int64
#  5   Number in series      597 non-null    int64
#  6   US viewers (million)  591 non-null    object
#  7   Views                 593 non-null    float64
#  8   IMDB rating           594 non-null    object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 42.1+ KB

# %% [markdown]
# Nota-se que
# - 'no_val' pode ser convertido para NaN
# - Air Date não está sendo interpretada como Datetime
# - Podemos utilizar a coluna 'Production Code' como sendo o index do dataframe

# %%
col_names = ['Title', 'Air date', 'Production code', 'Season', 'Number in season',
             'Number in series', 'US viewers (million)', 'Views', 'IMDB rating']

df = pd.read_csv('files/simpsons-episodes.tsv',
                 header=None,
                 names=col_names,
                 sep='\t',
                 skiprows=4,
                 encoding='UTF-8',
                 na_values='no_val',
                 parse_dates=['Air date'],
                 index_col='Production code')

df.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12640\1382164979.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv('files/simpsons-episodes.tsv',
#                                                              Title   Air date  \
# Production code
# 7F01             Two Cars in Every Garage and Three Eyes on Eve... 1990-01-11
# 7F08                                                           NaN 1990-11-15
# 7F06                                            Bart the Daredevil 1990-06-12
# NaN                                         Bart Gets Hit by a Car 1991-10-01
# 7F13                        Homer vs. Lisa and the 8th Commandment 1991-07-02
#
#                  Season  Number in season  Number in series  \
# Production code
# 7F01                2.0                 4                17
# 7F08                2.0                 6                19
# 7F06                2.0                 8                21
# NaN                 2.0                10                23
# 7F13                2.0                13                26
#
#                  US viewers (million)    Views  IMDB rating
# Production code
# 7F01                             26.1  64959.0          8.1
# 7F08                             25.4  50691.0          8.0
# 7F06                             26.2  57605.0          NaN
# NaN                              24.8  56486.0          7.8
# 7F13                             26.2  58277.0          8.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 597 entries, 7F01 to SABF13
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Title                 575 non-null    object
#  1   Air date              597 non-null    datetime64[ns]
#  2   Season                594 non-null    float64
#  3   Number in season      597 non-null    int64
#  4   Number in series      597 non-null    int64
#  5   US viewers (million)  588 non-null    float64
#  6   Views                 593 non-null    float64
#  7   IMDB rating           592 non-null    float64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(1)
# memory usage: 42.0+ KB

# %% [markdown]
# Como foi especificado somente algumas colunas do dataframe, vamos dropar as desnecessarias

# %%
select_cols = ['Title','Air date','Production code','IMDB rating']

colsToDrop = []
for col in df.columns:
    if col not in select_cols:
        colsToDrop.append(col)

df = df.drop(columns=colsToDrop)
df.head()
# Out:
#                                                              Title   Air date  \
# Production code
# 7F01             Two Cars in Every Garage and Three Eyes on Eve... 1990-01-11
# 7F08                                                           NaN 1990-11-15
# 7F06                                            Bart the Daredevil 1990-06-12
# NaN                                         Bart Gets Hit by a Car 1991-10-01
# 7F13                        Homer vs. Lisa and the 8th Commandment 1991-07-02
#
#                  IMDB rating
# Production code
# 7F01                     8.1
# 7F08                     8.0
# 7F06                     NaN
# NaN                      7.8
# 7F13                     8.0

# %% [markdown]
# # Testes

# %%
def test_df_columns():
    return list(df.columns) == ['Title', 'Air date', 'IMDB rating']

def test_df_item():
    return df.iloc[234, 2] == 6.6

def test_df_shape():
    return df.shape == (597, 3)

# %%
test_df_columns()
# Out:
# True

# %%
test_df_item()
# Out:
# True

# %%
test_df_shape()
# Out:
# True
