# %% [markdown]
# # Solução

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('files/movies.csv', 
                header=None,
                sep='|',
                names=['color', 'director_name', 'num_critic_for_reviews', 'duration',
                'gross', 'movie_title', 'num_user_for_reviews',	'country',
                'cotent_rating', 'budget', 'title_year', 'imdb_score', 'genre'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   color                   100 non-null    object
#  1   director_name           100 non-null    object
#  2   num_critic_for_reviews  100 non-null    object
#  3   duration                100 non-null    object
#  4   gross                   100 non-null    object
#  5   movie_title             100 non-null    object
#  6   num_user_for_reviews    100 non-null    object
#  7   country                 100 non-null    object
#  8   cotent_rating           100 non-null    object
#  9   budget                  100 non-null    object
#  10  title_year              100 non-null    object
#  11  imdb_score              100 non-null    float64
#  12  genre                   100 non-null    object
# dtypes: float64(1), object(12)
# memory usage: 10.3+ KB

# %%
df.head()
# Out:
#    color      director_name num_critic_for_reviews duration        gross  \
# 0  Color      James Cameron                  723.0    178.0  760505847.0
# 1  Color     Gore Verbinski                  302.0    169.0  309404152.0
# 2  Color         Sam Mendes                  602.0    148.0  200074175.0
# 3  Color  Christopher Nolan                  813.0    164.0  448130642.0
# 4      ?        Doug Walker                      ?        ?            ?
#
#                                          movie_title num_user_for_reviews  \
# 0                                            Avatar                3054.0
# 1          Pirates of the Caribbean: At World's End                1238.0
# 2                                           Spectre                 994.0
# 3                             The Dark Knight Rises                2701.0
# 4  Star Wars: Episode VII - The Force Awakens    ...                    ?
#
#   country cotent_rating         budget title_year  imdb_score        genre
# ...

# %% [markdown]
# Note que temos valores '?'. Vamos considerar esses valores como sendo NaN ao carregar os dados

# %%
df = pd.read_csv('files/movies.csv', 
                header=None,
                sep='|',
                names=['color', 'director_name', 'num_critic_for_reviews', 'duration',
                'gross', 'movie_title', 'num_user_for_reviews',	'country',
                'cotent_rating', 'budget', 'title_year', 'imdb_score', 'genre'],
                na_values='?')

df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration        gross  \
# 0  Color      James Cameron                   723.0     178.0  760505847.0
# 1  Color     Gore Verbinski                   302.0     169.0  309404152.0
# 2  Color         Sam Mendes                   602.0     148.0  200074175.0
# 3  Color  Christopher Nolan                   813.0     164.0  448130642.0
# 4    NaN        Doug Walker                     NaN       NaN          NaN
#
#                                          movie_title  num_user_for_reviews  \
# 0                                            Avatar                 3054.0
# 1          Pirates of the Caribbean: At World's End                 1238.0
# 2                                           Spectre                  994.0
# 3                             The Dark Knight Rises                 2701.0
# 4  Star Wars: Episode VII - The Force Awakens    ...                   NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   color                   99 non-null     object
#  1   director_name           100 non-null    object
#  2   num_critic_for_reviews  99 non-null     float64
#  3   duration                99 non-null     float64
#  4   gross                   97 non-null     float64
#  5   movie_title             100 non-null    object
#  6   num_user_for_reviews    99 non-null     float64
#  7   country                 99 non-null     object
#  8   cotent_rating           98 non-null     object
#  9   budget                  96 non-null     object
#  10  title_year              99 non-null     float64
#  11  imdb_score              100 non-null    float64
#  12  genre                   100 non-null    object
# dtypes: float64(6), object(7)
# memory usage: 10.3+ KB

# %% [markdown]
# A coluna budget não está sendo interpretada como int, isso é devido a ',' que veio com o dataset
#
# Além disso, podemos considerar a coluna 'movie_title' como sendo o index do dataframe

# %%
df = pd.read_csv('files/movies.csv', 
                header=None,
                sep='|',
                names=['color', 'director_name', 'num_critic_for_reviews', 'duration',
                'gross', 'movie_title', 'num_user_for_reviews',	'country',
                'cotent_rating', 'budget', 'title_year', 'imdb_score', 'genre'],
                na_values='?',
                thousands=',',
                index_col='movie_title')

df.head()
# Out:
#                                                     color      director_name  \
# movie_title
# Avatar                                              Color      James Cameron
# Pirates of the Caribbean: At World's End            Color     Gore Verbinski
# Spectre                                             Color         Sam Mendes
# The Dark Knight Rises                               Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens     ...    NaN        Doug Walker
#
#                                                     num_critic_for_reviews  \
# movie_title
# Avatar                                                               723.0
# Pirates of the Caribbean: At World's End                             302.0
# Spectre                                                              602.0
# The Dark Knight Rises                                                813.0
# Star Wars: Episode VII - The Force Awakens     ...                     NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, Avatar  to The Hobbit: An Unexpected Journey
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   color                   99 non-null     object
#  1   director_name           100 non-null    object
#  2   num_critic_for_reviews  99 non-null     float64
#  3   duration                99 non-null     float64
#  4   gross                   97 non-null     float64
#  5   num_user_for_reviews    99 non-null     float64
#  6   country                 99 non-null     object
#  7   cotent_rating           98 non-null     object
#  8   budget                  96 non-null     float64
#  9   title_year              99 non-null     float64
#  10  imdb_score              100 non-null    float64
#  11  genre                   100 non-null    object
# dtypes: float64(7), object(5)
# memory usage: 10.2+ KB

# %% [markdown]
# # Testes

# %%
def test_score():
    return df.loc[:, 'imdb_score'].max() == 9

def test_shape():
    return df.shape == (100, 12)

# %%
test_score()
# Out:
# True

# %%
test_shape()
# Out:
# True
